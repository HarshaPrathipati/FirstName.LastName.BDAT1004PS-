# %%
import pandas as pd

# %%
romanEmperors = pd.read_csv('roman-emperor-reigns.csv')
romanEmperors.head()
# Out:
#     Emperor  Length_of_Reign         Cause_of_Death
# 0  Augustus            40.58  Possibly assassinated
# 1  Tiberius            22.50  Possibly assassinated
# 2  Caligula             4.83           Assassinated
# 3  Claudius            13.75  Possibly assassinated
# 4      Nero            13.67                Suicide

# %%
re = romanEmperors.value_counts(subset='Cause_of_Death')
re.plot.pie(y='Causes_of_Death',ylabel='',figsize=(7,7),autopct='%1.0f%%',title = 'Causes of Death')
# Out:
# <AxesSubplot:title={'center':'Causes of Death'}>
